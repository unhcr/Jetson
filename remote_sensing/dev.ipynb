# %%
import data_utils

# %%
from landsatxplore.earthexplorer import EarthExplorer

ee = EarthExplorer("barcanjo", "Guitarra915641448")

ee.download('LC08_L1TP_163058_20220427_20220427_02_RT', output_dir='./data')

ee.logout()
# Out:
#   1%|          | 7.21M/1.26G [00:01<05:53, 3.79MB/s]
# ---------------------------------------------------------------------------
# EarthExplorerError                        Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\landsatxplore\earthexplorer.py:168, in EarthExplorer.download(self, identifier, output_dir, dataset, timeout, skip)
#     <a href='file:///c%3A/Users/barca/AppData/Local/Programs/Python/Python39/lib/site-packages/landsatxplore/earthexplorer.py?line=164'>165</a>     url = EE_DOWNLOAD_URL.format(
#     <a href='file:///c%3A/Users/barca/AppData/Local/Programs/Python/Python39/lib/site-packages/landsatxplore/earthexplorer.py?line=165'>166</a>         data_product_id=DATA_PRODUCTS[dataset], entity_id=entity_id
#     <a href='file:///c%3A/Users/barca/AppData/Local/Programs/Python/Python39/lib/site-packages/landsatxplore/earthexplorer.py?line=166'>167</a>     )
# ...

# %%
data_utils.download_region_data("banadir", "barcanjo", "Guitarra915641448")
# Out:
# {'cloud_cover': 32.6, 'entity_id': 'LC81630582022117LGN00', 'display_id': 'LC08_L1TP_163058_20220427_20220427_02_RT', 'ordering_id': 'None', 'landsat_product_id': 'LC08_L1TP_163058_20220427_20220427_02_RT', 'landsat_scene_id': 'LC81630582022117LGN00', 'acquisition_date': datetime.datetime(2022, 4, 27, 0, 0), 'collection_category': 'RT', 'collection_number': 2, 'wrs_path': 163, 'wrs_row': 58, 'nadir-off_nadir': 'NADIR', 'roll_angle': -0.001, 'date_product_generated': datetime.datetime(2022, 4, 27, 0, 0), 'land_cloud_cover': 38.73, 'scene_cloud_cover': 32.6, 'start_time': datetime.datetime(2022, 4, 27, 7, 10, 35, 382584), 'stop_time': datetime.datetime(2022, 4, 27, 7, 11, 7, 152584), 'station_id': 'LGN', 'day-night_indicator': 'DAY', 'ground_control_points_model': 115, 'ground_control_points_version': 5, 'geometric_rmse_model': 8.487, 'geometric_rmse_model_x': 5.714, 'geometric_rmse_model_y': 6.275, 'image_quality': 9, 'processing_software_version': 'LPGS_15.6.0', 'sun_elevation_l0ra':
# ...
